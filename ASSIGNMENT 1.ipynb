# %%
#QUESTION 1

my_dict={"NAME":"VED","STD":12,"ROLL NO.":20,"STREAM":"SCI","CITY":"PUNE"}
print(my_dict)
# Out:
# {'NAME': 'VED', 'STD': 12, 'ROLL NO.': 20, 'STREAM': 'SCI', 'CITY': 'PUNE'}

# %%
my_dict["EMAIL"]="XYZ@GAMIL.COM"
print(my_dict)
# Out:
# {'NAME': 'VED', 'STD': 12, 'ROLL NO.': 20, 'STREAM': 'SCI', 'CITY': 'PUNE', 'EMAIL': 'XYZ@GAMIL.COM'}

# %%
# QUESTION 2
list1=["name","panel","rollno"]
list2=["ABC","b",34]
dict1=dict(zip(list1,list2))
print(dict1)
# Out:
# {'name': 'ABC', 'panel': 'b', 'rollno': 34}

# %%
#QUESTION 3
my_dict={"name":"ABC","panel":"B","rollno":34,"marks":[65,87,67,94]}
x=sorted(my_dict)
print("sorted",x)
# Out:
# sorted ['marks', 'name', 'panel', 'rollno']

# %%
#QUESTION 4
x={"a":10,"b":20,"c":40,"d":50}
y=list(x.keys())
z=list(x.values())
print("key",y)
print("values",z)
# Out:
# key ['a', 'b', 'c', 'd']
# values [10, 20, 40, 50]

# %%
#QUESTION 5
my_dict={"marks1":23,"marks2":123,"marks3":43,"marks4":13,"marks5":39}
x=sum(my_dict.values())/len(my_dict.keys())
print("mean of this",x)
# Out:
# mean of this 48.2

# %%
#QUESTION 6
my_dict={"name":["yash","neel","dev"],"rollno":[11,12,13,],"marks":[78,56,89,]}
print(my_dict)

print(my_dict["name"][2])

print(my_dict["rollno"][1])

print(max(my_dict["marks"]))
# Out:
# {'name': ['yash', 'neel', 'dev'], 'rollno': [11, 12, 13], 'marks': [78, 56, 89]}
# dev
# 12
# 89

# %%
#QUESTION 7
string =input("enter a string:")
frequency={}
for ch in string:
    if ch in frequency:
        frequency[ch] +=1
    else:
        frequency[ch]=1
print("frequency:",frequency)
# Out:
# enter a string: a
# frequency: {'a': 1}

# %%
#QUESTION 8
n=int(input("enter numerator:"))
d=int(input("enter denominator:"))
q=n//d
r=n%d
result=(q,r)
print(result)
# Out:
# enter numerator: 10
# enter denominator: 20
# (0, 10)

# %%
#QUESTION 9
from datetime import date 
d1=int(input("enter day of first date :"))
m1=int(input("enter month of first date :"))
y1=int(input("enter year of first date :"))

d2=int(input("enter day of second date :"))
m2=int(input("enter month of second date :"))
y2=int(input("enter year of second date :"))

date1=date(y1,m1,d1)
date2=date(y2,m2,d2)
difference=abs((date2-date1).days)
print("number of days between dates:",difference)
# Out:
# enter day of first date : 10
# enter month of first date : 2
# enter year of first date : 2025
# enter day of second date : 20
# enter month of second date : 2
# enter year of second date : 2026
# number of days between dates: 375
